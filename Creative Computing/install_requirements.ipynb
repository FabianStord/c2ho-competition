# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Collecting git+https://github.com/tensorflow/docs (from -r requirements.txt (line 11))
#   Cloning https://github.com/tensorflow/docs to /private/var/folders/fs/8gqgy4197v356238z0x_qxlc0000gn/T/pip-req-build-qtcq4swx
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/docs /private/var/folders/fs/8gqgy4197v356238z0x_qxlc0000gn/T/pip-req-build-qtcq4swx
#   Resolved https://github.com/tensorflow/docs to commit ba879887790ded183c04540d5386df4962f48eeb
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: matplotlib in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: librosa in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.10.0.post2)
# Requirement already satisfied: Pillow in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (9.5.0)
# Collecting tensorflow
#   Using cached tensorflow-2.12.0-cp39-cp39-macosx_10_15_x86_64.whl (230.1 MB)
# Requirement already satisfied: moviepy in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.0.3)
# Requirement already satisfied: imageio in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (2.28.1)
# Requirement already satisfied: scipy in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.10.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (23.0)
# Requirement already satisfied: cycler>=0.10 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (0.3.5)
# Requirement already satisfied: joblib>=0.14 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: pooch<1.7,>=1.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (0.2)
# Requirement already satisfied: audioread>=2.1.9 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (4.4.2)
# Requirement already satisfied: msgpack>=1.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: numba>=0.51.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (0.57.0)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 4)) (0.12.1)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.0-py2.py3-none-macosx_10_9_x86_64.whl (26.7 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.32.0-cp39-cp39-macosx_10_14_x86_64.whl (1.7 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.54.0-cp39-cp39-macosx_10_10_universal2.whl (8.7 MB)
# Requirement already satisfied: six>=1.12.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 6)) (1.16.0)
# Collecting numpy
#   Using cached numpy-1.23.5-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Using cached tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting wrapt<1.15,>=1.11.0
#   Using cached wrapt-1.14.1-cp39-cp39-macosx_10_9_x86_64.whl (35 kB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.5.8-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 6)) (66.0.0)
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Collecting keras<2.13,>=2.12.0
#   Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.23.0-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.8.0-cp39-cp39-macosx_10_9_x86_64.whl (3.2 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.9.tar.gz (1.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: proglog<=1.0.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from moviepy->-r requirements.txt (line 8)) (0.1.10)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from moviepy->-r requirements.txt (line 8)) (4.65.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from moviepy->-r requirements.txt (line 8)) (0.4.8)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from moviepy->-r requirements.txt (line 8)) (2.29.0)
# Collecting astor
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: jinja2 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: nbformat in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (5.7.0)
# Collecting pyyaml
#   Using cached PyYAML-6.0-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 6)) (0.38.4)
# Requirement already satisfied: zipp>=3.1.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 3)) (3.11.0)
# Collecting ml-dtypes>=0.1.0
#   Using cached ml_dtypes-0.1.0-cp39-cp39-macosx_10_9_universal2.whl (317 kB)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from numba>=0.51.0->librosa->-r requirements.txt (line 4)) (0.40.0)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 8)) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 8)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 8)) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 8)) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa->-r requirements.txt (line 4)) (1.15.1)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.18.0-py2.py3-none-any.whl (178 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.3.4-py3-none-any.whl (242 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.0-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from jinja2->tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (2.1.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from nbformat->tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (4.17.3)
# Requirement already satisfied: fastjsonschema in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from nbformat->tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (2.16.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from nbformat->tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (5.7.1)
# Requirement already satisfied: jupyter-core in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from nbformat->tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (5.3.0)
# Requirement already satisfied: pycparser in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->-r requirements.txt (line 4)) (2.21)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: attrs>=17.4.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (0.18.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow->-r requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (from jupyter-core->nbformat->tensorflow-docs==0.0.0.dev0->-r requirements.txt (line 11)) (2.5.2)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: tensorflow-docs, jax
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0.dev0-py3-none-any.whl size=183465 sha256=4cd4ea5cafeaa35756738319d6d593747571fa1d7ea28a31fed7c65b2dcb4797
#   Stored in directory: /private/var/folders/fs/8gqgy4197v356238z0x_qxlc0000gn/T/pip-ephem-wheel-cache-qz42rdqj/wheels/fc/f8/3b/5d21409a59cb1be9b1ade11f682039ced75b84de9dd6a0c8de
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.9-py3-none-any.whl size=1477708 sha256=f4662d1e54679f7ab3490691a82096762dc5d503d6a80c70ceb10aded06c0ccc
#   Stored in directory: /Users/Kristian/Library/Caches/pip/wheels/2e/27/88/3feb4541c1b051f9380c0b190088a2da62bb9b3fbf27c12dd3
# Successfully built tensorflow-docs jax
# Installing collected packages: libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyyaml, pyasn1, protobuf, oauthlib, numpy, keras, grpcio, google-pasta, gast, cachetools, astunparse, astor, absl-py, rsa, requests-oauthlib, pyasn1-modules, opt-einsum, ml-dtypes, markdown, h5py, tensorflow-docs, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Successfully installed absl-py-1.4.0 astor-0.8.1 astunparse-1.6.3 cachetools-5.3.0 flatbuffers-23.5.8 gast-0.4.0 google-auth-2.18.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.0 h5py-3.8.0 jax-0.4.9 keras-2.12.0 libclang-16.0.0 markdown-3.4.3 ml-dtypes-0.1.0 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.0 pyasn1-0.5.0 pyasn1-modules-0.3.0 pyyaml-6.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.3 tensorboard-data-server-0.7.0 tensorflow-2.12.0 tensorflow-docs-0.0.0.dev0 tensorflow-estimator-2.12.0 tensorflow-io-gcs-filesystem-0.32.0 termcolor-2.3.0 werkzeug-2.3.4 wrapt-1.14.1

# %%
pip install ffmpeg --upgrade
# Out:
# Requirement already satisfied: ffmpeg in /Users/Kristian/opt/anaconda3/envs/C2HO/lib/python3.9/site-packages (1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from tensorflow.keras.utils import img_to_array
from keras.layers import Dense, Conv2D, MaxPooling2D, UpSampling2D, Dropout
from keras.models import Sequential
from keras.callbacks import LambdaCallback
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import imageio
import tensorflow_docs.vis.embed as embed
from PIL import Image
import glob
import re
import librosa
from IPython.display import Audio
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavefile
from moviepy.editor import *

print(bytearray.fromhex("53756363657373").decode())
# Out:
# Success
